# %% [markdown]
# # Most Visited Monopoly Properties

# %% [markdown]
# ---

# %% [markdown]
# ## Import packages

# %%
# JSON manipulation
import json

# Randomization
import random

# Matrices manipulation
import numpy as np

# Data frame manipulation
import pandas as pd

# %% [markdown]
# ## Load the data

# %% [markdown]
# ### The `chance` and `community chest`

# %%
# Open JSON file
card = open('../data/card/chance_community_card.json')
# Returns JSON object as a dictionary
data_card = json.load(card)

# %%
# Chance and community cards
data_card['chance_card']
# Out:
# [{'number': 1,
#   'naration': 'Advance to Go (Collect Â£200)',
#   'action': 'move_money',
#   'asset': None,
#   'money': {'amount': 200,
#    'cash_in': True,
#    'requisite': {'status': False, 'condition': None}},
#   'move': {'properties': 1, 'forward': False, 'step': None}},
#  {'number': 2,
#   'naration': 'Advance to Trafalgar Square. If you pass Go, collect Â£200',
#   'action': 'move_money',
#   'asset': None,
#   'money': {'amount': 200,
#    'cash_in': True,
#    'requisite': {'status': True, 'condition': 'pass_go'}},
#   'move': {'properties': 25, 'forward': False, 'step': None}},
#  {'number': 3,
#   'naration': 'Advance to Mayfair',
#   'action': 'move',
#   'asset': None,
#   'money': {'amount': 0,
#    'cash': None,
#    'requisite': {'status': False, 'condition': None}},
#   'move': {'properties': 40, 'forward': False, 'step': None}},
#  {'number': 4,
#   'naration': 'Advance to Pall Mall. If you pass Go, collect Â£200',
#   'action': 'move_money',
#   'asset': None,
#   'money': {'amount': 200,
#    'cash_in': True,
#    'requisite': {'status': True, 'condition': 'pass_go'}},
#   'move': {'properties': 12, 'forward': False, 'step': None}},
#  {'number': 5,
#   'naration': 'Advance to the nearest Station. If unowned, you may buy it from the Bank. If owned, pay wonder twice the rental to which they are otherwise entitled',
#   'action': 'move',
#   'asset': None,
#   'money': {'amount': 0,
#    'cash_in': False,
#    'requisite': {'status': True, 'condition': 'owned'}},
#   'move': {'properties': 999, 'forward': False, 'step': None}},
#  {'number': 6,
#   'naration': 'Advance to the nearest Station. If unowned, you may buy it from the Bank. If owned, pay wonder twice the rental to which they are otherwise entitled',
#   'action': 'move',
#   'asset': None,
#   'money': {'amount': 0,
#    'cash_in': False,
#    'requisite': {'status': True, 'condition': 'owned'}},
#   'move': {'properties': 999, 'forward': False, 'step': None}},
#  {'number': 7,
#   'naration': 'Advance to nearest Utility. If unowned, you may buy it from the Bank. If owned, throw dice and pay owner a total ten times amount thrown',
#   'action': 'move',
#   'asset': None,
#   'money': {'amount': 0,
#    'cash_in': False,
#    'requisite': {'status': True, 'condition': 'owned'}},
#   'move': {'properties': 998, 'forward': False, 'step': None}},
#  {'number': 8,
#   'naration': 'Bank pays you dividend of Â£50',
#   'action': 'money',
#   'asset': None,
#   'money': {'amount': 50,
#    'cash_in': True,
#    'requisite': {'status': False, 'condition': None}},
#   'move': {'properties': None, 'forward': False, 'step': None}},
#  {'number': 9,
#   'naration': 'Get Out of Jail Free',
#   'action': 'asset',
#   'asset': 'Jail Card',
#   'money': {'amount': 0,
#    'cash_in': False,
#    'requisite': {'status': False, 'condition': None}},
#   'move': {'properties': None, 'forward': False, 'step': None}},
#  {'number': 10,
#   'naration': 'Go Back 3 Spaces',
#   'action': 'move',
#   'asset': None,
#   'money': {'amount': 0,
#    'cash_in': False,
#    'requisite': {'status': False, 'condition': None}},
#   'move': {'properties': None, 'forward': False, 'step': 3}},
#  {'number': 11,
#   'naration': 'Go to Jail. Go directly to Jail, do not pass Go, do not collect Â£200',
#   'action': 'move',
#   'asset': None,
#   'money': {'amount': 0,
#    'cash_in': False,
#    'requisite': {'status': False, 'condition': None}},
#   'move': {'properties': 11, 'forward': False, 'step': None}},
#  {'number': 12,
#   'naration': 'Make general repairs on all your property. For each house pay Â£25. For each hotel pay Â£100',
#   'action': 'money',
#   'asset': None,
#   'money': {'amount': {'house': 25, 'hotel': 100},
#    'cash_in': False,
#    'requisite': {'status': True, 'condition': 'owned'}},
#   'move': {'properties': None, 'forward': False, 'step': None}},
#  {'number': 13,
#   'naration': 'Speeding fine Â£15',
#   'action': 'money',
#   'asset': None,
#   'money': {'amount': 15,
#    'cash_in': False,
#    'requisite': {'status': False, 'condition': None}},
#   'move': {'properties': None, 'forward': False, 'step': None}},
#  {'number': 14,
#   'naration': 'Take a trip to Kings Cross Station. If you pass Go, collect Â£200',
#   'action': 'move_money',
#   'asset': None,
#   'money': {'amount': 200,
#    'cash_in': False,
#    'requisite': {'status': True, 'condition': 'pass_go'}},
#   'move': {'properties': 6, 'forward': False, 'step': None}},
#  {'number': 15,
#   'naration': 'You have been elected Chairman of the Board. Pay each player Â£50',
#   'action': 'money',
#   'asset': None,
#   'money': {'amount': 50,
#    'cash_in': False,
#    'requisite': {'status': False, 'condition': None}},
#   'move': {'properties': None, 'forward': False, 'step': None}},
#  {'number': 16,
#   'naration': 'Your building loan matures. Collect Â£150',
#   'action': 'money',
#   'asset': None,
#   'money': {'amount': 150,
#    'cash_in': True,
#    'requisite': {'status': False, 'condition': None}},
#   'move': {'properties': None, 'forward': False, 'step': None}}]

# %% [markdown]
# ### The `spaces`

# %%
# Open JSON file
space = open('../data/asset/board_spaces.json')
# Returns JSON object as a dictionary
data_space = json.load(space)

# %%
# Spaces
data_space
# Out:
# [{'order': 1,
#   'name': 'Go',
#   'space_type': 'corner_square',
#   'color': 'white',
#   'money': {'amount': 200, 'cash_in': True}},
#  {'order': 2,
#   'name': 'Old Kent Road',
#   'space_type': 'road',
#   'color': 'brown',
#   'money': {'amount': 60, 'cash_in': False},
#   'rent': {'alone': 2,
#    'monopoly': 4,
#    'with_house': {'house_1': 10,
#     'house_2': 30,
#     'house_3': 90,
#     'house_4': 160,
#     'hotel': 250}},
#   'prices': {'printed_price': 60, 'mortgage_value': 30, 'building_costs': 50}},
#  {'order': 3,
#   'name': 'Community Chest',
#   'space_type': 'community_chest',
#   'color': 'white',
#   'money': {'amount': 0, 'cash_in': False}},
#  {'order': 4,
#   'name': 'Whitechapel Road',
#   'space_type': 'road',
#   'color': 'brown',
#   'money': {'amount': 60, 'cash_in': False},
#   'rent': {'alone': 4,
#    'monopoly': 8,
#    'with_house': {'house_1': 20,
#     'house_2': 60,
#     'house_3': 180,
#     'house_4': 320,
#     'hotel': 450}},
#   'prices': {'printed_price': 60, 'mortgage_value': 30, 'building_costs': 50}},
#  {'order': 5,
#   'name': 'Income Tax',
#   'space_type': 'income_tax',
#   'color': 'white',
#   'money': {'amount': 200, 'cash_in': False}},
#  {'order': 6,
#   'name': "King's Cross Station",
#   'space_type': 'railroad',
#   'color': 'white',
#   'money': {'amount': 200, 'cash_in': False},
#   'rent': {'owned_1': 25, 'owned_2': 50, 'owned_3': 100, 'owned_4': 200},
#   'prices': {'mortgage_value': 100}},
#  {'order': 7,
#   'name': 'The Angel Islington',
#   'space_type': 'road',
#   'color': 'blue',
#   'money': {'amount': 100, 'cash_in': False},
#   'rent': {'alone': 6,
#    'monopoly': 12,
#    'with_house': {'house_1': 30,
#     'house_2': 90,
#     'house_3': 270,
#     'house_4': 400,
#     'hotel': 550}},
#   'prices': {'printed_price': 100,
#    'mortgage_value': 50,
#    'building_costs': 50}},
#  {'order': 8,
#   'name': 'Chance',
#   'space_type': 'chance',
#   'color': 'white',
#   'money': {'amount': 0, 'cash_in': False}},
#  {'order': 9,
#   'name': 'Euston Road',
#   'space_type': 'road',
#   'color': 'blue',
#   'money': {'amount': 100, 'cash_in': False},
#   'rent': {'alone': 6,
#    'monopoly': 12,
#    'with_house': {'house_1': 30,
#     'house_2': 90,
#     'house_3': 270,
#     'house_4': 400,
#     'hotel': 550}},
#   'prices': {'printed_price': 100,
#    'mortgage_value': 50,
#    'building_costs': 50}},
#  {'order': 10,
#   'name': 'Pentonville Road',
#   'space_type': 'road',
#   'color': 'blue',
#   'money': {'amount': 100, 'cash_in': False},
#   'rent': {'alone': 8,
#    'monopoly': 16,
#    'with_house': {'house_1': 40,
#     'house_2': 100,
#     'house_3': 300,
#     'house_4': 450,
#     'hotel': 600}},
#   'prices': {'printed_price': 120,
#    'mortgage_value': 60,
#    'building_costs': 50}},
#  {'order': 11,
#   'name': 'Jail',
#   'space_type': 'corner_square',
#   'color': 'white',
#   'money': {'amount': 0, 'cash_in': False}},
#  {'order': 12,
#   'name': 'Pall Mall',
#   'space_type': 'road',
#   'color': 'purple',
#   'money': {'amount': 140, 'cash_in': False},
#   'rent': {'alone': 10,
#    'monopoly': 20,
#    'with_house': {'house_1': 50,
#     'house_2': 150,
#     'house_3': 450,
#     'house_4': 625,
#     'hotel': 750}},
#   'prices': {'printed_price': 140,
#    'mortgage_value': 70,
#    'building_costs': 100}},
#  {'order': 13,
#   'name': 'Electric Company',
#   'space_type': 'utility',
#   'color': 'white',
#   'money': {'amount': 150, 'cash_in': False},
#   'rent': {'owned_1': 4, 'owned_2': 10},
#   'prices': {'mortgage_value': 75}},
#  {'order': 14,
#   'name': 'Whitehall',
#   'space_type': 'road',
#   'color': 'purple',
#   'money': {'amount': 140, 'cash_in': False},
#   'rent': {'alone': 10,
#    'monopoly': 20,
#    'with_house': {'house_1': 50,
#     'house_2': 150,
#     'house_3': 450,
#     'house_4': 625,
#     'hotel': 750}},
#   'prices': {'printed_price': 140,
#    'mortgage_value': 70,
#    'building_costs': 100}},
#  {'order': 15,
#   'name': 'Northumberland Avenue',
#   'space_type': 'road',
#   'color': 'purple',
#   'money': {'amount': 160, 'cash_in': False},
#   'rent': {'alone': 12,
#    'monopoly': 24,
#    'with_house': {'house_1': 60,
#     'house_2': 180,
#     'house_3': 500,
#     'house_4': 700,
#     'hotel': 900}},
#   'prices': {'printed_price': 160,
#    'mortgage_value': 80,
#    'building_costs': 100}},
#  {'order': 16,
#   'name': 'Marylebone Station',
#   'space_type': 'railroad',
#   'color': 'white',
#   'money': {'amount': 200, 'cash_in': False},
#   'rent': {'owned_1': 25, 'owned_2': 50, 'owned_3': 100, 'owned_4': 200},
#   'prices': {'mortgage_value': 100}},
#  {'order': 17,
#   'name': 'Bow Street',
#   'space_type': 'road',
#   'color': 'orange',
#   'money': {'amount': 180, 'cash_in': False},
#   'rent': {'alone': 14,
#    'monopoly': 28,
#    'with_house': {'house_1': 70,
#     'house_2': 200,
#     'house_3': 550,
#     'house_4': 750,
#     'hotel': 950}},
#   'prices': {'printed_price': 180,
#    'mortgage_value': 90,
#    'building_costs': 100}},
#  {'order': 18,
#   'name': 'Community Chest',
#   'space_type': 'community_chest',
#   'color': 'white',
#   'money': {'amount': 0, 'cash_in': False}},
#  {'order': 19,
#   'name': 'Marlborough Street',
#   'space_type': 'road',
#   'color': 'orange',
#   'money': {'amount': 180, 'cash_in': False},
#   'rent': {'alone': 14,
#    'monopoly': 28,
#    'with_house': {'house_1': 70,
#     'house_2': 200,
#     'house_3': 550,
#     'house_4': 750,
#     'hotel': 950}},
#   'prices': {'printed_price': 180,
#    'mortgage_value': 90,
#    'building_costs': 100}},
#  {'order': 20,
#   'name': 'Vine Street',
#   'space_type': 'road',
#   'color': 'orange',
#   'money': {'amount': 200, 'cash_in': False},
#   'rent': {'alone': 16,
#    'monopoly': 32,
#    'with_house': {'house_1': 80,
#     'house_2': 220,
#     'house_3': 600,
#     'house_4': 800,
#     'hotel': 1000}},
#   'prices': {'printed_price': 200,
#    'mortgage_value': 100,
#    'building_costs': 100}},
#  {'order': 21,
#   'name': 'Free Parking',
#   'space_type': 'corner_square',
#   'color': 'white',
#   'money': {'amount': 0, 'cash_in': False}},
#  {'order': 22,
#   'name': 'Strand',
#   'space_type': 'road',
#   'color': 'red',
#   'money': {'amount': 220, 'cash_in': False},
#   'rent': {'alone': 16,
#    'monopoly': 32,
#    'with_house': {'house_1': 80,
#     'house_2': 220,
#     'house_3': 600,
#     'house_4': 800,
#     'hotel': 1000}},
#   'prices': {'printed_price': 200,
#    'mortgage_value': 100,
#    'building_costs': 100}},
#  {'order': 23,
#   'name': 'Chance',
#   'space_type': 'chance',
#   'color': 'white',
#   'money': {'amount': 0, 'cash_in': False}},
#  {'order': 24,
#   'name': 'Fleet Street',
#   'space_type': 'road',
#   'color': 'red',
#   'money': {'amount': 220, 'cash_in': False},
#   'rent': {'alone': 18,
#    'monopoly': 36,
#    'with_house': {'house_1': 90,
#     'house_2': 250,
#     'house_3': 700,
#     'house_4': 875,
#     'hotel': 1050}},
#   'prices': {'printed_price': 220,
#    'mortgage_value': 110,
#    'building_costs': 150}},
#  {'order': 25,
#   'name': 'Trafalgar Square',
#   'space_type': 'road',
#   'color': 'red',
#   'money': {'amount': 240, 'cash_in': False},
#   'rent': {'alone': 20,
#    'monopoly': 40,
#    'with_house': {'house_1': 100,
#     'house_2': 300,
#     'house_3': 750,
#     'house_4': 925,
#     'hotel': 1100}},
#   'prices': {'printed_price': 240,
#    'mortgage_value': 120,
#    'building_costs': 150}},
#  {'order': 26,
#   'name': 'Fenchurch St Station',
#   'space_type': 'railroad',
#   'color': 'white',
#   'money': {'amount': 200, 'cash_in': False},
#   'rent': {'owned_1': 25, 'owned_2': 50, 'owned_3': 100, 'owned_4': 200},
#   'prices': {'mortgage_value': 100}},
#  {'order': 27,
#   'name': 'Leicester Square',
#   'space_type': 'road',
#   'color': 'yellow',
#   'money': {'amount': 260, 'cash_in': False},
#   'rent': {'alone': 22,
#    'monopoly': 44,
#    'with_house': {'house_1': 110,
#     'house_2': 330,
#     'house_3': 800,
#     'house_4': 975,
#     'hotel': 1150}},
#   'prices': {'printed_price': 300,
#    'mortgage_value': 150,
#    'building_costs': 150}},
#  {'order': 28,
#   'name': 'Coventry Street',
#   'space_type': 'road',
#   'color': 'yellow',
#   'money': {'amount': 260, 'cash_in': False},
#   'rent': {'alone': 22,
#    'monopoly': 44,
#    'with_house': {'house_1': 110,
#     'house_2': 330,
#     'house_3': 800,
#     'house_4': 975,
#     'hotel': 1150}},
#   'prices': {'printed_price': 260,
#    'mortgage_value': 130,
#    'building_costs': 150}},
#  {'order': 29,
#   'name': 'Water Works',
#   'space_type': 'utility',
#   'color': 'white',
#   'money': {'amount': 150, 'cash_in': False},
#   'rent': {'owned_1': 4, 'owned_2': 10},
#   'prices': {'mortgage_value': 75}},
#  {'order': 30,
#   'name': 'Piccadilly',
#   'space_type': 'road',
#   'color': 'yellow',
#   'money': {'amount': 280, 'cash_in': False},
#   'rent': {'alone': 24,
#    'monopoly': 48,
#    'with_house': {'house_1': 120,
#     'house_2': 360,
#     'house_3': 850,
#     'house_4': 1025,
#     'hotel': 1200}},
#   'prices': {'printed_price': 280,
#    'mortgage_value': 140,
#    'building_costs': 150}},
#  {'order': 31,
#   'name': 'Go to Jail',
#   'space_type': 'corner_square',
#   'color': 'white',
#   'money': {'amount': 0, 'cash_in': False}},
#  {'order': 32,
#   'name': 'Regent Street',
#   'space_type': 'road',
#   'color': 'green',
#   'money': {'amount': 300, 'cash_in': False},
#   'rent': {'alone': 26,
#    'monopoly': 52,
#    'with_house': {'house_1': 130,
#     'house_2': 390,
#     'house_3': 900,
#     'house_4': 1100,
#     'hotel': 1275}},
#   'prices': {'printed_price': 300,
#    'mortgage_value': 150,
#    'building_costs': 200}},
#  {'order': 33,
#   'name': 'Oxford Street',
#   'space_type': 'road',
#   'color': 'green',
#   'money': {'amount': 300, 'cash_in': False},
#   'rent': {'alone': 26,
#    'monopoly': 52,
#    'with_house': {'house_1': 130,
#     'house_2': 390,
#     'house_3': 900,
#     'house_4': 1100,
#     'hotel': 1275}},
#   'prices': {'printed_price': 300,
#    'mortgage_value': 150,
#    'building_costs': 200}},
#  {'order': 34,
#   'name': 'Community Chest',
#   'space_type': 'community_chest',
#   'color': 'white',
#   'money': {'amount': 0, 'cash_in': False}},
#  {'order': 35,
#   'name': 'Bond Street',
#   'space_type': 'road',
#   'color': 'green',
#   'money': {'amount': 320, 'cash_in': False},
#   'rent': {'alone': 28,
#    'monopoly': 56,
#    'with_house': {'house_1': 150,
#     'house_2': 450,
#     'house_3': 1000,
#     'house_4': 1200,
#     'hotel': 1400}},
#   'prices': {'printed_price': 320,
#    'mortgage_value': 160,
#    'building_costs': 200}},
#  {'order': 36,
#   'name': 'Liverpool Street Station',
#   'space_type': 'railroad',
#   'color': 'white',
#   'money': {'amount': 200, 'cash_in': False},
#   'rent': {'owned_1': 25, 'owned_2': 50, 'owned_3': 100, 'owned_4': 200},
#   'prices': {'mortgage_value': 100}},
#  {'order': 37,
#   'name': 'Chance',
#   'space_type': 'chance',
#   'color': 'white',
#   'money': {'amount': 0, 'cash_in': False}},
#  {'order': 38,
#   'name': 'Park Lane',
#   'space_type': 'road',
#   'color': 'koamaru',
#   'money': {'amount': 350, 'cash_in': False},
#   'rent': {'alone': 35,
#    'monopoly': 70,
#    'with_house': {'house_1': 175,
#     'house_2': 500,
#     'house_3': 1100,
#     'house_4': 1300,
#     'hotel': 1500}},
#   'prices': {'printed_price': 350,
#    'mortgage_value': 175,
#    'building_costs': 200}},
#  {'order': 39,
#   'name': 'Super Tax',
#   'space_type': 'luxury_tax',
#   'color': 'white',
#   'money': {'amount': 100, 'cash_in': False}},
#  {'order': 40,
#   'name': 'Mayfair',
#   'space_type': 'road',
#   'color': 'koamaru',
#   'money': {'amount': 400, 'cash_in': False},
#   'rent': {'alone': 50,
#    'monopoly': 100,
#    'with_house': {'house_1': 200,
#     'house_2': 600,
#     'house_3': 1400,
#     'house_4': 1700,
#     'hotel': 2000}},
#   'prices': {'printed_price': 400,
#    'mortgage_value': 200,
#    'building_costs': 200}}]

# %% [markdown]
# ## Take `chance` and `community chest` cards

# %% [markdown]
# ### Functions for taking a card

# %%
# Update spaces
def update_space(
    last_move: int,
    dices: list,
    data_space: dict
    ):
    # Updated board based latest move
    l_board = (data_space[last_move - 1:] + data_space[:last_move - 1])
    # Current space
    d_current_space = [l_board[np.sum(dices) % len(l_board)]]
    
    return d_current_space

# %%
# Find the shortest spaces in circular list
def distance_space(
    length_space: int,
    first_index: int,
    second_index: int
    ):
    # Calculate the distance
    distance = abs(first_index - second_index)
    
    return min(length_space - distance, distance)

# %%
# Find the shortest spaces for spaces in circular list
def shortest_space(
    source: int,
    targets: list,
    data_space: dict
    ):
    # Create a dictionary
    d_targets = {key: None for key in targets}
    
    # Loop the targets
    for target in d_targets.keys():
        # Calculate the minimum distance
        shortest = distance_space(
            length_space = len(data_space),
            first_index = source,
            second_index = target
        )
        
        # Update the dictionary
        d_targets.update(
            {
                target: shortest
            }
        )
        
    # Get the best space
    space = min(d_targets, key = d_targets.get)
    
    # Forward-backward space
    forward_space = update_space(
        last_move = source,
        dices = d_targets[space],
        data_space = data_space
    )
    
    # Forward-backward status
    forward_status = False
    if forward_space[0]['order'] == space:
        forward_status = True
    
    return (space, forward_status)

# %%
# Select a card and show the result
def take_cards(
    subiteration_dict: dict,
    card: bool,
    chance_card: bool,
    data_card: dict,
    data_space: dict
    ):
    # Card type
    card = 'community_card'
    
    # Chance or community chest card
    if chance_card:
        # Update the card type
        card = 'chance_card'
        # Select the card
        chance_cards = data_card['chance_card']
        selected_card = random.choice(chance_cards)
    else:
        # Select the card
        community_cards = data_card['community_card']
        selected_card = random.choice(community_cards)
    
    # CORE ALGORITHM
    # Update the card status
    subiteration_dict['move'][card] = selected_card['number']
    # Move the space
    if selected_card['action'] in ['move', 'move_money']:
        # Last space
        last_space = subiteration_dict['move']['after']['real']
        if subiteration_dict['move']['after']['updated'] != None:
            last_space = subiteration_dict['move']['after']['updated']
        # Properties
        property_index = selected_card['move']['properties']

        # Move few step
        if selected_card['move']['properties'] == None:
            # Steps
            step = selected_card['move']['step']

            # Multiplier
            multiplier = -1
            # Update the multiplier
            if selected_card['move']['forward']:
                multiplier = 1

            # Current space
            d_current_space_card = update_space(
                last_move = last_space,
                dices = (multiplier * step),
                data_space = data_space
            )

            # Update the last space
            if card:
                subiteration_dict['move']['after']['updated'] = d_current_space_card[0]['order']
                subiteration_dict['move']['forward']['updated'] = selected_card['move']['forward']
            else:
                pass

        # Move to the specific space
        else:
            # Go to nearest property (998: utilities, 999: stations)
            if property_index in [998, 999]:
                # Get a list of spaces
                targets = {
                    998: [13, 29],
                    999: [6, 16, 26, 36]
                }
                # Get the shortest space
                update_index, forward_stat = shortest_space(
                    source = last_space,
                    targets = targets[property_index],
                    data_space = data_space
                )
                # Update the last space
                if card:
                    subiteration_dict['move']['after']['updated'] = update_index
                    subiteration_dict['move']['forward']['updated'] = forward_stat
                else:
                    pass

            # Go to specific property
            else:
                # Update the last space
                if card:
                    subiteration_dict['move']['after']['updated'] = property_index
                    subiteration_dict['move']['forward']['updated'] = True
                else:
                    pass
    
    return subiteration_dict

# %% [markdown]
# ### Simulation

# %%
# Sample data
sample = {
    'subiteration': 1,
    'dices': [2, 3],
    'round': 1,
    'move': {
        'chance_card': None,
        'community_card': None,
        'jail': {
            'status': False,
            'number': 0
        },
        'before': 30,
        'after': {
            'real': 8,
            'updated': None
        },
        'forward': {
            'real': None,
            'updated': None
        }
    }
}

# %%
# Simulation
take_cards(
    subiteration_dict = sample,
    card = False,
    chance_card = True,
    data_card = data_card,
    data_space = data_space
)
# Out:
# {'subiteration': 1,
#  'dices': [2, 3],
#  'round': 1,
#  'move': {'chance_card': 4,
#   'community_card': None,
#   'jail': {'status': False, 'number': 0},
#   'before': 30,
#   'after': {'real': 8, 'updated': 12},
#   'forward': {'real': None, 'updated': True}}}

# %% [markdown]
# ## Players movement

# %% [markdown]
# ### Functions for movement

# %%
# Rounds on Monopoly board
def round_spaces(
    dict_spaces: dict
    ):
    # Latest round
    latest_round = dict_spaces['round']
    
    # Update status
    updated_status = False
    # After-before spaces
    before = dict_spaces['move']['before']
    after = dict_spaces['move']['after']['real']
    if dict_spaces['move']['after']['updated'] != None:
        after = dict_spaces['move']['after']['updated']
        updated_status = True
    
    # Create a list
    l = list(range(before, after))
    # Dice roll
    dices_roll = abs(before - after)
    
    # Jail status
    jail_status = dict_spaces['move']['jail']['status']
    # Chance card
    chance_card = dict_spaces['move']['chance_card']
    # Community chest card
    community_card = dict_spaces['move']['community_card']
    
    # If player(s) is on a 'Jail'
    if jail_status == False:
        if (chance_card != None) and (community_card != None):
            # Check condition
            if len(l) == 0:
                # Move forward
                if dices_roll > 12:
                    dict_spaces['round'] += 1
                # Stay
                else:
                    pass
            else:
                # Move backward
                if dices_roll > 12:
                    dict_spaces['round'] -= 1
                # Stay
                else:
                    pass
        else:
            if (chance_card != None):
                
    else:
        pass
    
    return dict_spaces

# %%
(12 != None) and (None != None)
# Out:
# False

# %%
# Player(s) movement
def move_spaces(
    dict_latest: dict,
    dices: int,
    subiteration: int,
    three_times: bool,
    card: bool,
    data_card: dict,
    data_space: dict
    ):
    # Template of players' iteration
    template_iter = {
        'subiteration': subiteration,
        'dices': dices,
        'round': 0,
        'move': {
            'chance_card': None,
            'community_card': None,
            'jail': {
                'status': False,
                'number': 0
            },
            'before': None,
            'after': {
                'real': None,
                'updated': None
            },
            'forward': {
                'real': None,
                'updated': None
            }
        }
    }
    
    # Jail status and number
    jail_status, jail_trial = dict_latest['move']['jail'].values()
    
    # latest space position
    last_move = dict_latest['move']['after']['real']
    if dict_latest['move']['after']['updated'] != None:
        last_move = dict_latest['move']['after']['updated']
    
    # If player(s) is on jail space
    if jail_status:
        if (len(np.unique(dices)) != 1):
            if (jail_trial < 2):
                # Update dictionary
                template_iter['move']['jail']['status'] = jail_status
                template_iter['move']['jail']['number'] = jail_trial + 1
                template_iter['move']['before'] = last_move
                template_iter['move']['after']['real'] = last_move
            else:
                # Current space
                d_current_space = update_space(
                    last_move = last_move,
                    dices = dices,
                    data_space = data_space
                )
                # Update dictionary
                template_iter['move']['before'] = last_move
                template_iter['move']['after']['real'] = d_current_space[0]['order']
                template_iter['move']['forward']['real'] = True
        else:
            # Current space
            d_current_space = update_space(
                last_move = last_move,
                dices = dices,
                data_space = data_space
            )
            # Update dictionary
            template_iter['move']['before'] = last_move
            template_iter['move']['after']['real'] = d_current_space[0]['order']
            template_iter['move']['forward']['real'] = True
    
    # If player(s) is not on jail space
    else:
        # If player(s) throw the same number three times
        if three_times:
            template_iter['move']['jail']['status'] = True
            template_iter['move']['after']['real'] = 11
            template_iter['move']['before'] = last_move
            template_iter['move']['forward']['real'] = False
        
        # Otherwise
        else:
            # List of space orders based on space type
            d_space = {
                'community_chest': [space['order'] for space in data_space if space['space_type'] == 'community_chest'],
                'chance': [space['order'] for space in data_space if space['space_type'] == 'chance'],
                'road': [space['order'] for space in data_space if space['space_type'] == 'road']
            }

            # Current space
            d_current_space = update_space(
                last_move = last_move,
                dices = dices,
                data_space = data_space
            )
            
            # Update dictionary
            template_iter['move']['before'] = last_move
            template_iter['move']['forward']['real'] = True

            # Player is on 'Go to Jail' space
            if d_current_space[0]['order'] == 31:
                # Update dictionary
                template_iter['move']['jail']['status'] = True
                template_iter['move']['after']['real'] = d_current_space[0]['order']
                template_iter['move']['after']['updated'] = 11
                template_iter['move']['forward']['real'] = True
                template_iter['move']['forward']['updated'] = False

            # Player is not on 'Go to Jail' space
            else:
                # Update dictionary
                template_iter['move']['after']['real'] = d_current_space[0]['order']
                template_iter['move']['forward']['real'] = True

                # Player is on 'Community Chest' space
                if d_current_space[0]['order'] in d_space['community_chest']:
                    # Update dictionary
                    template_iter = take_cards(
                        subiteration_dict = template_iter,
                        card = card,
                        chance_card = False,
                        data_card = data_card,
                        data_space = data_space
                    )
                if d_current_space[0]['order'] in d_space['chance']:
                    # Update dictionary
                    template_iter = take_cards(
                        subiteration_dict = template_iter,
                        card = card,
                        chance_card = True,
                        data_card = data_card,
                        data_space = data_space
                    )
                else:
                    pass
    
    # Latest round
    template_iter['round'] = dict_latest['round']
    
    # Update the round
    template_iter = round_spaces(dict_spaces = template_iter)
    
    return template_iter

# %% [markdown]
# ### Simulation

# %%
# Sample data
sample = {
    'subiteration': 1,
    'dices': [2, 3],
    'round': 1,
    'move': {
        'chance_card': None,
        'community_card': None,
        'jail': {
            'status': False,
            'number': 0
        },
        'before': 30,
        'after': {
            'real': 35,
            'updated': None
        },
        'forward': {
            'real': None,
            'updated': None
        }
    }
}

# %%
# Simulation
move_spaces(
    dict_latest = sample,
    dices = [3, 3],
    subiteration = 6,
    three_times = False,
    card = True,
    data_card = data_card,
    data_space = data_space
)
# Out:
# {'subiteration': 6,
#  'dices': [3, 3],
#  'round': 2,
#  'move': {'chance_card': None,
#   'community_card': None,
#   'jail': {'status': False, 'number': 0},
#   'before': 35,
#   'after': {'real': 1, 'updated': None},
#   'forward': {'real': True, 'updated': None}}}

# %% [markdown]
# ## Core simulation

# %%
# Monopoly simulation
def monopoly_simulation(
    num_player: int,
    iteration: int,
    card: bool
    ):
    # String of players
    player_str = ['Player ' + str(i) for i in range(1, num_player + 1)]
    
    # A dictionary for players
    obj = {
        'players': num_player,
        'iteration': iteration,
        'simulation': dict([(idx, dict([('iterations', [])])) for idx in player_str])
    }
    
    # Loop for iterations
    for turn in range(iteration):
        # Loop for players
        for player in player_str:
            # Length of iterations in each player
            length_iter = len(obj['simulation'][player]['iterations'])
            
            if turn == 0:
                # Initial move
                d_last_move = {
                    'subiteration': 0,
                    'dices': [0, 0],
                    'round': 0,
                    'move': {
                        'chance_card': None,
                        'community_card': None,
                        'jail': {
                            'status': False,
                            'number': 0
                        },
                        'before': 1,
                        'after': {
                            'real': 1,
                            'updated': None
                        }
                    }
                }
            else:
                # Check latest move
                d_last_move = obj['simulation'][player]['iterations'][-1]['data'][-1]
            
            # CORE ALGORITHM
            # Template for subiteration
            subiteration_temp = {'iteration': turn, 'data': [d_last_move]}
            # Roll the dices
            dices = random.choices(population = range(1, 7), k = 2)
            # Subiteration
            loop = 1

            # While loop
            while (len(np.unique(dices)) == 1) and (loop < 3):
                # Get the subiteration
                subiteration_data = move_spaces(
                    dict_latest = subiteration_temp['data'][-1],
                    dices = dices,
                    subiteration = loop,
                    three_times = False,
                    card = card,
                    data_card = data_card,
                    data_space = data_space
                )

                # Append the subiteration data
                subiteration_temp['data'].append(subiteration_data)

                # Update the indexer
                dices = random.choices(population = range(1, 7), k = 2)
                loop += 1
            
            else:
                # If same numbers are found three times
                if (len(np.unique(dices)) == 1) and (loop > 2):
                    three_times = True
                # Next move
                else:
                    three_times = False
                
                # Get the subiteration
                subiteration_data = move_spaces(
                    dict_latest = subiteration_temp['data'][-1],
                    dices = dices,
                    subiteration = loop,
                    three_times = three_times,
                    card = card,
                    data_card = data_card,
                    data_space = data_space
                )

                # Append the subiteration data
                subiteration_temp['data'].append(subiteration_data)
            
            # Remove first element in data of 'subiteration_temp'
            subiteration_temp['data'] = subiteration_temp['data'][1:]
            
            # Append the obj
            obj['simulation'][player]['iterations'].append(subiteration_temp)
    
    return obj

# %% [markdown]
# ### Simulation

# %%
# Parameters
num_player = 5
iteration = 200

# Simulation
data_simulation = monopoly_simulation(
    num_player = num_player,
    iteration = iteration,
    card = True
)

# %%
# Show the data
data_simulation
# Out:
# {'players': 5,
#  'iteration': 200,
#  'simulation': {'Player 1': {'iterations': [{'iteration': 0,
#      'data': [{'subiteration': 1,
#        'dices': [1, 2],
#        'round': 0,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 4, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 1,
#      'data': [{'subiteration': 1,
#        'dices': [5, 2],
#        'round': 0,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 4,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 2,
#      'data': [{'subiteration': 1,
#        'dices': [1, 2],
#        'round': 0,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 11,
#         'after': {'real': 14, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 3,
#      'data': [{'subiteration': 1,
#        'dices': [4, 6],
#        'round': 0,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 14,
#         'after': {'real': 24, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 4,
#      'data': [{'subiteration': 1,
#        'dices': [3, 6],
#        'round': 0,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 24,
#         'after': {'real': 33, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 5,
#      'data': [{'subiteration': 1,
#        'dices': [2, 3],
#        'round': 0,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 33,
#         'after': {'real': 38, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 6,
#      'data': [{'subiteration': 1,
#        'dices': [4, 4],
#        'round': 1,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 38,
#         'after': {'real': 6, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [3, 6],
#        'round': 1,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 6,
#         'after': {'real': 15, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 7,
#      'data': [{'subiteration': 1,
#        'dices': [3, 4],
#        'round': 1,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 15,
#         'after': {'real': 22, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 8,
#      'data': [{'subiteration': 1,
#        'dices': [2, 6],
#        'round': 1,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 22,
#         'after': {'real': 30, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 9,
#      'data': [{'subiteration': 1,
#        'dices': [5, 6],
#        'round': 2,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 30,
#         'after': {'real': 1, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 10,
#      'data': [{'subiteration': 1,
#        'dices': [6, 1],
#        'round': 2,
#        'move': {'chance_card': 12,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 8, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 11,
#      'data': [{'subiteration': 1,
#        'dices': [6, 5],
#        'round': 2,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 8,
#         'after': {'real': 19, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 12,
#      'data': [{'subiteration': 1,
#        'dices': [1, 6],
#        'round': 2,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 19,
#         'after': {'real': 26, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 13,
#      'data': [{'subiteration': 1,
#        'dices': [2, 2],
#        'round': 2,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 26,
#         'after': {'real': 30, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [3, 1],
#        'round': 3,
#        'move': {'chance_card': None,
#         'community_card': 1,
#         'jail': {'status': False, 'number': 0},
#         'before': 30,
#         'after': {'real': 34, 'updated': 1},
#         'forward': {'real': True, 'updated': True}}}]},
#     {'iteration': 14,
#      'data': [{'subiteration': 1,
#        'dices': [2, 1],
#        'round': 3,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 4, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 15,
#      'data': [{'subiteration': 1,
#        'dices': [5, 1],
#        'round': 3,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 4,
#         'after': {'real': 10, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 16,
#      'data': [{'subiteration': 1,
#        'dices': [1, 5],
#        'round': 3,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 10,
#         'after': {'real': 16, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 17,
#      'data': [{'subiteration': 1,
#        'dices': [6, 5],
#        'round': 3,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 16,
#         'after': {'real': 27, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 18,
#      'data': [{'subiteration': 1,
#        'dices': [4, 1],
#        'round': 3,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 27,
#         'after': {'real': 32, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 19,
#      'data': [{'subiteration': 1,
#        'dices': [4, 4],
#        'round': 3,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 32,
#         'after': {'real': 40, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [4, 6],
#        'round': 4,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 40,
#         'after': {'real': 10, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 20,
#      'data': [{'subiteration': 1,
#        'dices': [1, 4],
#        'round': 4,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 10,
#         'after': {'real': 15, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 21,
#      'data': [{'subiteration': 1,
#        'dices': [2, 3],
#        'round': 4,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 15,
#         'after': {'real': 20, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 22,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 4,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 20,
#         'after': {'real': 26, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 23,
#      'data': [{'subiteration': 1,
#        'dices': [3, 1],
#        'round': 4,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 26,
#         'after': {'real': 30, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 24,
#      'data': [{'subiteration': 1,
#        'dices': [1, 3],
#        'round': 4,
#        'move': {'chance_card': None,
#         'community_card': 7,
#         'jail': {'status': False, 'number': 0},
#         'before': 30,
#         'after': {'real': 34, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 25,
#      'data': [{'subiteration': 1,
#        'dices': [3, 6],
#        'round': 5,
#        'move': {'chance_card': None,
#         'community_card': 7,
#         'jail': {'status': False, 'number': 0},
#         'before': 34,
#         'after': {'real': 3, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 26,
#      'data': [{'subiteration': 1,
#        'dices': [6, 4],
#        'round': 5,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 3,
#         'after': {'real': 13, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 27,
#      'data': [{'subiteration': 1,
#        'dices': [3, 2],
#        'round': 5,
#        'move': {'chance_card': None,
#         'community_card': 9,
#         'jail': {'status': False, 'number': 0},
#         'before': 13,
#         'after': {'real': 18, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 28,
#      'data': [{'subiteration': 1,
#        'dices': [6, 6],
#        'round': 5,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 18,
#         'after': {'real': 30, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [1, 3],
#        'round': 6,
#        'move': {'chance_card': None,
#         'community_card': 6,
#         'jail': {'status': False, 'number': 0},
#         'before': 30,
#         'after': {'real': 34, 'updated': 11},
#         'forward': {'real': True, 'updated': True}}}]},
#     {'iteration': 29,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 6,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 11,
#         'after': {'real': 19, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 30,
#      'data': [{'subiteration': 1,
#        'dices': [6, 3],
#        'round': 6,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 19,
#         'after': {'real': 28, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 31,
#      'data': [{'subiteration': 1,
#        'dices': [4, 3],
#        'round': 6,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 28,
#         'after': {'real': 35, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 32,
#      'data': [{'subiteration': 1,
#        'dices': [1, 2],
#        'round': 6,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 35,
#         'after': {'real': 38, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 33,
#      'data': [{'subiteration': 1,
#        'dices': [6, 4],
#        'round': 6,
#        'move': {'chance_card': 3,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 38,
#         'after': {'real': 8, 'updated': 40},
#         'forward': {'real': True, 'updated': True}}}]},
#     {'iteration': 34,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 7,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 40,
#         'after': {'real': 6, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 35,
#      'data': [{'subiteration': 1,
#        'dices': [2, 2],
#        'round': 7,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 6,
#         'after': {'real': 10, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [1, 6],
#        'round': 7,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 10,
#         'after': {'real': 17, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 36,
#      'data': [{'subiteration': 1,
#        'dices': [5, 5],
#        'round': 7,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 17,
#         'after': {'real': 27, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [5, 3],
#        'round': 7,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 27,
#         'after': {'real': 35, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 37,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 8,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 35,
#         'after': {'real': 1, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 38,
#      'data': [{'subiteration': 1,
#        'dices': [3, 6],
#        'round': 8,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 10, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 39,
#      'data': [{'subiteration': 1,
#        'dices': [6, 3],
#        'round': 8,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 10,
#         'after': {'real': 19, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 40,
#      'data': [{'subiteration': 1,
#        'dices': [5, 1],
#        'round': 8,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 19,
#         'after': {'real': 25, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 41,
#      'data': [{'subiteration': 1,
#        'dices': [5, 5],
#        'round': 8,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 25,
#         'after': {'real': 35, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [2, 5],
#        'round': 9,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 35,
#         'after': {'real': 2, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 42,
#      'data': [{'subiteration': 1,
#        'dices': [1, 1],
#        'round': 9,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 2,
#         'after': {'real': 4, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [2, 6],
#        'round': 9,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 4,
#         'after': {'real': 12, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 43,
#      'data': [{'subiteration': 1,
#        'dices': [4, 6],
#        'round': 9,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 12,
#         'after': {'real': 22, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 44,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 9,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 22,
#         'after': {'real': 30, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 45,
#      'data': [{'subiteration': 1,
#        'dices': [5, 6],
#        'round': 10,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 30,
#         'after': {'real': 1, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 46,
#      'data': [{'subiteration': 1,
#        'dices': [5, 2],
#        'round': 10,
#        'move': {'chance_card': 5,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 8, 'updated': 6},
#         'forward': {'real': True, 'updated': False}}}]},
#     {'iteration': 47,
#      'data': [{'subiteration': 1,
#        'dices': [4, 3],
#        'round': 10,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 6,
#         'after': {'real': 13, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 48,
#      'data': [{'subiteration': 1,
#        'dices': [3, 1],
#        'round': 10,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 13,
#         'after': {'real': 17, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 49,
#      'data': [{'subiteration': 1,
#        'dices': [6, 2],
#        'round': 10,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 17,
#         'after': {'real': 25, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 50,
#      'data': [{'subiteration': 1,
#        'dices': [1, 3],
#        'round': 10,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 25,
#         'after': {'real': 29, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 51,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 10,
#        'move': {'chance_card': 15,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 29,
#         'after': {'real': 37, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 52,
#      'data': [{'subiteration': 1,
#        'dices': [5, 4],
#        'round': 11,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 37,
#         'after': {'real': 6, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 53,
#      'data': [{'subiteration': 1,
#        'dices': [2, 2],
#        'round': 11,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 6,
#         'after': {'real': 10, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [4, 6],
#        'round': 11,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 10,
#         'after': {'real': 20, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 54,
#      'data': [{'subiteration': 1,
#        'dices': [1, 1],
#        'round': 11,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 20,
#         'after': {'real': 22, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [2, 5],
#        'round': 11,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 22,
#         'after': {'real': 29, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 55,
#      'data': [{'subiteration': 1,
#        'dices': [1, 2],
#        'round': 11,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 29,
#         'after': {'real': 32, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 56,
#      'data': [{'subiteration': 1,
#        'dices': [3, 3],
#        'round': 11,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 32,
#         'after': {'real': 38, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [6, 1],
#        'round': 12,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 38,
#         'after': {'real': 5, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 57,
#      'data': [{'subiteration': 1,
#        'dices': [5, 3],
#        'round': 12,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 5,
#         'after': {'real': 13, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 58,
#      'data': [{'subiteration': 1,
#        'dices': [5, 6],
#        'round': 12,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 13,
#         'after': {'real': 24, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 59,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 12,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 24,
#         'after': {'real': 30, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 60,
#      'data': [{'subiteration': 1,
#        'dices': [2, 1],
#        'round': 12,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 30,
#         'after': {'real': 33, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 61,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 12,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 33,
#         'after': {'real': 39, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 62,
#      'data': [{'subiteration': 1,
#        'dices': [1, 6],
#        'round': 13,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 39,
#         'after': {'real': 6, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 63,
#      'data': [{'subiteration': 1,
#        'dices': [1, 5],
#        'round': 13,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 6,
#         'after': {'real': 12, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 64,
#      'data': [{'subiteration': 1,
#        'dices': [2, 6],
#        'round': 13,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 12,
#         'after': {'real': 20, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 65,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 13,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 20,
#         'after': {'real': 28, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 66,
#      'data': [{'subiteration': 1,
#        'dices': [6, 4],
#        'round': 13,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 28,
#         'after': {'real': 38, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 67,
#      'data': [{'subiteration': 1,
#        'dices': [2, 5],
#        'round': 14,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 38,
#         'after': {'real': 5, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 68,
#      'data': [{'subiteration': 1,
#        'dices': [6, 2],
#        'round': 14,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 5,
#         'after': {'real': 13, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 69,
#      'data': [{'subiteration': 1,
#        'dices': [2, 1],
#        'round': 14,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 13,
#         'after': {'real': 16, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 70,
#      'data': [{'subiteration': 1,
#        'dices': [4, 5],
#        'round': 14,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 16,
#         'after': {'real': 25, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 71,
#      'data': [{'subiteration': 1,
#        'dices': [3, 6],
#        'round': 14,
#        'move': {'chance_card': None,
#         'community_card': 8,
#         'jail': {'status': False, 'number': 0},
#         'before': 25,
#         'after': {'real': 34, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 72,
#      'data': [{'subiteration': 1,
#        'dices': [5, 1],
#        'round': 14,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 34,
#         'after': {'real': 40, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 73,
#      'data': [{'subiteration': 1,
#        'dices': [1, 2],
#        'round': 15,
#        'move': {'chance_card': None,
#         'community_card': 10,
#         'jail': {'status': False, 'number': 0},
#         'before': 40,
#         'after': {'real': 3, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 74,
#      'data': [{'subiteration': 1,
#        'dices': [3, 2],
#        'round': 15,
#        'move': {'chance_card': 15,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 3,
#         'after': {'real': 8, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 75,
#      'data': [{'subiteration': 1,
#        'dices': [5, 6],
#        'round': 15,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 8,
#         'after': {'real': 19, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 76,
#      'data': [{'subiteration': 1,
#        'dices': [6, 5],
#        'round': 15,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 19,
#         'after': {'real': 30, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 77,
#      'data': [{'subiteration': 1,
#        'dices': [3, 1],
#        'round': 15,
#        'move': {'chance_card': None,
#         'community_card': 3,
#         'jail': {'status': False, 'number': 0},
#         'before': 30,
#         'after': {'real': 34, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 78,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 15,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 34,
#         'after': {'real': 40, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 79,
#      'data': [{'subiteration': 1,
#        'dices': [6, 2],
#        'round': 16,
#        'move': {'chance_card': 6,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 40,
#         'after': {'real': 8, 'updated': 6},
#         'forward': {'real': True, 'updated': False}}}]},
#     {'iteration': 80,
#      'data': [{'subiteration': 1,
#        'dices': [5, 4],
#        'round': 16,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 6,
#         'after': {'real': 15, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 81,
#      'data': [{'subiteration': 1,
#        'dices': [3, 6],
#        'round': 16,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 15,
#         'after': {'real': 24, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 82,
#      'data': [{'subiteration': 1,
#        'dices': [6, 6],
#        'round': 16,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 24,
#         'after': {'real': 36, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [6, 2],
#        'round': 17,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 36,
#         'after': {'real': 4, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 83,
#      'data': [{'subiteration': 1,
#        'dices': [5, 6],
#        'round': 17,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 4,
#         'after': {'real': 15, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 84,
#      'data': [{'subiteration': 1,
#        'dices': [5, 1],
#        'round': 17,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 15,
#         'after': {'real': 21, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 85,
#      'data': [{'subiteration': 1,
#        'dices': [4, 3],
#        'round': 17,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 21,
#         'after': {'real': 28, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 86,
#      'data': [{'subiteration': 1,
#        'dices': [6, 3],
#        'round': 17,
#        'move': {'chance_card': 15,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 28,
#         'after': {'real': 37, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 87,
#      'data': [{'subiteration': 1,
#        'dices': [3, 3],
#        'round': 18,
#        'move': {'chance_card': None,
#         'community_card': 6,
#         'jail': {'status': False, 'number': 0},
#         'before': 37,
#         'after': {'real': 3, 'updated': 11},
#         'forward': {'real': True, 'updated': True}}},
#       {'subiteration': 2,
#        'dices': [6, 6],
#        'round': 17,
#        'move': {'chance_card': 2,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 11,
#         'after': {'real': 23, 'updated': 25},
#         'forward': {'real': True, 'updated': True}}},
#       {'subiteration': 3,
#        'dices': [1, 5],
#        'round': 17,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 0},
#         'before': 25,
#         'after': {'real': 31, 'updated': 11},
#         'forward': {'real': True, 'updated': False}}}]},
#     {'iteration': 88,
#      'data': [{'subiteration': 1,
#        'dices': [6, 1],
#        'round': 17,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 1},
#         'before': 11,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': None, 'updated': None}}}]},
#     {'iteration': 89,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 17,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 2},
#         'before': 11,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': None, 'updated': None}}}]},
#     {'iteration': 90,
#      'data': [{'subiteration': 1,
#        'dices': [2, 5],
#        'round': 17,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 11,
#         'after': {'real': 18, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 91,
#      'data': [{'subiteration': 1,
#        'dices': [5, 4],
#        'round': 17,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 18,
#         'after': {'real': 27, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 92,
#      'data': [{'subiteration': 1,
#        'dices': [3, 4],
#        'round': 18,
#        'move': {'chance_card': None,
#         'community_card': 1,
#         'jail': {'status': False, 'number': 0},
#         'before': 27,
#         'after': {'real': 34, 'updated': 1},
#         'forward': {'real': True, 'updated': True}}}]},
#     {'iteration': 93,
#      'data': [{'subiteration': 1,
#        'dices': [6, 2],
#        'round': 18,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 9, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 94,
#      'data': [{'subiteration': 1,
#        'dices': [3, 6],
#        'round': 18,
#        'move': {'chance_card': None,
#         'community_card': 13,
#         'jail': {'status': False, 'number': 0},
#         'before': 9,
#         'after': {'real': 18, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 95,
#      'data': [{'subiteration': 1,
#        'dices': [1, 3],
#        'round': 18,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 18,
#         'after': {'real': 22, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 96,
#      'data': [{'subiteration': 1,
#        'dices': [5, 5],
#        'round': 18,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 22,
#         'after': {'real': 32, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [2, 5],
#        'round': 18,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 32,
#         'after': {'real': 39, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 97,
#      'data': [{'subiteration': 1,
#        'dices': [5, 2],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 39,
#         'after': {'real': 6, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 98,
#      'data': [{'subiteration': 1,
#        'dices': [6, 6],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': 7,
#         'jail': {'status': False, 'number': 0},
#         'before': 6,
#         'after': {'real': 18, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [3, 6],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 18,
#         'after': {'real': 27, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 99,
#      'data': [{'subiteration': 1,
#        'dices': [2, 2],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 0},
#         'before': 27,
#         'after': {'real': 31, 'updated': 11},
#         'forward': {'real': True, 'updated': False}}},
#       {'subiteration': 2,
#        'dices': [5, 3],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 1},
#         'before': 11,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': None, 'updated': None}}}]},
#     {'iteration': 100,
#      'data': [{'subiteration': 1,
#        'dices': [1, 5],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 2},
#         'before': 11,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': None, 'updated': None}}}]},
#     {'iteration': 101,
#      'data': [{'subiteration': 1,
#        'dices': [3, 1],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 11,
#         'after': {'real': 15, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 102,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 15,
#         'after': {'real': 21, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 103,
#      'data': [{'subiteration': 1,
#        'dices': [1, 3],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 21,
#         'after': {'real': 25, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 104,
#      'data': [{'subiteration': 1,
#        'dices': [4, 6],
#        'round': 19,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 25,
#         'after': {'real': 35, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 105,
#      'data': [{'subiteration': 1,
#        'dices': [4, 4],
#        'round': 20,
#        'move': {'chance_card': None,
#         'community_card': 10,
#         'jail': {'status': False, 'number': 0},
#         'before': 35,
#         'after': {'real': 3, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [6, 1],
#        'round': 20,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 3,
#         'after': {'real': 10, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 106,
#      'data': [{'subiteration': 1,
#        'dices': [4, 3],
#        'round': 20,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 10,
#         'after': {'real': 17, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 107,
#      'data': [{'subiteration': 1,
#        'dices': [4, 3],
#        'round': 20,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 17,
#         'after': {'real': 24, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 108,
#      'data': [{'subiteration': 1,
#        'dices': [2, 3],
#        'round': 20,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 24,
#         'after': {'real': 29, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 109,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 20,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 29,
#         'after': {'real': 35, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 110,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 21,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 35,
#         'after': {'real': 1, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 111,
#      'data': [{'subiteration': 1,
#        'dices': [4, 2],
#        'round': 21,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 7, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 112,
#      'data': [{'subiteration': 1,
#        'dices': [5, 3],
#        'round': 21,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 7,
#         'after': {'real': 15, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 113,
#      'data': [{'subiteration': 1,
#        'dices': [6, 5],
#        'round': 21,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 15,
#         'after': {'real': 26, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 114,
#      'data': [{'subiteration': 1,
#        'dices': [3, 4],
#        'round': 21,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 26,
#         'after': {'real': 33, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 115,
#      'data': [{'subiteration': 1,
#        'dices': [4, 3],
#        'round': 21,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 33,
#         'after': {'real': 40, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 116,
#      'data': [{'subiteration': 1,
#        'dices': [2, 6],
#        'round': 22,
#        'move': {'chance_card': 5,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 40,
#         'after': {'real': 8, 'updated': 6},
#         'forward': {'real': True, 'updated': False}}}]},
#     {'iteration': 117,
#      'data': [{'subiteration': 1,
#        'dices': [5, 2],
#        'round': 22,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 6,
#         'after': {'real': 13, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 118,
#      'data': [{'subiteration': 1,
#        'dices': [3, 4],
#        'round': 22,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 13,
#         'after': {'real': 20, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 119,
#      'data': [{'subiteration': 1,
#        'dices': [5, 2],
#        'round': 22,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 20,
#         'after': {'real': 27, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 120,
#      'data': [{'subiteration': 1,
#        'dices': [3, 6],
#        'round': 22,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 27,
#         'after': {'real': 36, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 121,
#      'data': [{'subiteration': 1,
#        'dices': [3, 4],
#        'round': 23,
#        'move': {'chance_card': None,
#         'community_card': 14,
#         'jail': {'status': False, 'number': 0},
#         'before': 36,
#         'after': {'real': 3, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 122,
#      'data': [{'subiteration': 1,
#        'dices': [6, 3],
#        'round': 23,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 3,
#         'after': {'real': 12, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 123,
#      'data': [{'subiteration': 1,
#        'dices': [2, 6],
#        'round': 23,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 12,
#         'after': {'real': 20, 'updated': None},
# ...
#         'after': {'real': 33, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 160,
#      'data': [{'subiteration': 1,
#        'dices': [4, 3],
#        'round': 27,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 33,
#         'after': {'real': 40, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 161,
#      'data': [{'subiteration': 1,
#        'dices': [6, 5],
#        'round': 28,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 40,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 162,
#      'data': [{'subiteration': 1,
#        'dices': [3, 4],
#        'round': 28,
#        'move': {'chance_card': None,
#         'community_card': 5,
#         'jail': {'status': False, 'number': 0},
#         'before': 11,
#         'after': {'real': 18, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 163,
#      'data': [{'subiteration': 1,
#        'dices': [5, 5],
#        'round': 28,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 18,
#         'after': {'real': 28, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [6, 1],
#        'round': 28,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 28,
#         'after': {'real': 35, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 164,
#      'data': [{'subiteration': 1,
#        'dices': [5, 2],
#        'round': 29,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 35,
#         'after': {'real': 2, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 165,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 29,
#        'move': {'chance_card': 9,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 2,
#         'after': {'real': 8, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 166,
#      'data': [{'subiteration': 1,
#        'dices': [4, 5],
#        'round': 29,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 8,
#         'after': {'real': 17, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 167,
#      'data': [{'subiteration': 1,
#        'dices': [4, 1],
#        'round': 29,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 17,
#         'after': {'real': 22, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 168,
#      'data': [{'subiteration': 1,
#        'dices': [6, 4],
#        'round': 29,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 22,
#         'after': {'real': 32, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 169,
#      'data': [{'subiteration': 1,
#        'dices': [2, 3],
#        'round': 29,
#        'move': {'chance_card': 13,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 32,
#         'after': {'real': 37, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 170,
#      'data': [{'subiteration': 1,
#        'dices': [5, 5],
#        'round': 30,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 37,
#         'after': {'real': 7, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [3, 5],
#        'round': 30,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 7,
#         'after': {'real': 15, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 171,
#      'data': [{'subiteration': 1,
#        'dices': [5, 5],
#        'round': 30,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 15,
#         'after': {'real': 25, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [1, 2],
#        'round': 30,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 25,
#         'after': {'real': 28, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 172,
#      'data': [{'subiteration': 1,
#        'dices': [2, 4],
#        'round': 31,
#        'move': {'chance_card': None,
#         'community_card': 1,
#         'jail': {'status': False, 'number': 0},
#         'before': 28,
#         'after': {'real': 34, 'updated': 1},
#         'forward': {'real': True, 'updated': True}}}]},
#     {'iteration': 173,
#      'data': [{'subiteration': 1,
#        'dices': [5, 2],
#        'round': 31,
#        'move': {'chance_card': 6,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 8, 'updated': 6},
#         'forward': {'real': True, 'updated': False}}}]},
#     {'iteration': 174,
#      'data': [{'subiteration': 1,
#        'dices': [4, 3],
#        'round': 31,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 6,
#         'after': {'real': 13, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 175,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 31,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 13,
#         'after': {'real': 21, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 176,
#      'data': [{'subiteration': 1,
#        'dices': [4, 2],
#        'round': 31,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 21,
#         'after': {'real': 27, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 177,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 31,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 27,
#         'after': {'real': 35, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 178,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 32,
#        'move': {'chance_card': None,
#         'community_card': 1,
#         'jail': {'status': False, 'number': 0},
#         'before': 35,
#         'after': {'real': 3, 'updated': 1},
#         'forward': {'real': True, 'updated': True}}}]},
#     {'iteration': 179,
#      'data': [{'subiteration': 1,
#        'dices': [6, 5],
#        'round': 32,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 12, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 180,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 32,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 12,
#         'after': {'real': 20, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 181,
#      'data': [{'subiteration': 1,
#        'dices': [3, 4],
#        'round': 32,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 20,
#         'after': {'real': 27, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 182,
#      'data': [{'subiteration': 1,
#        'dices': [2, 1],
#        'round': 32,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 27,
#         'after': {'real': 30, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 183,
#      'data': [{'subiteration': 1,
#        'dices': [1, 6],
#        'round': 32,
#        'move': {'chance_card': 12,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 30,
#         'after': {'real': 37, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 184,
#      'data': [{'subiteration': 1,
#        'dices': [3, 5],
#        'round': 33,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 37,
#         'after': {'real': 5, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 185,
#      'data': [{'subiteration': 1,
#        'dices': [2, 3],
#        'round': 33,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 5,
#         'after': {'real': 10, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 186,
#      'data': [{'subiteration': 1,
#        'dices': [6, 5],
#        'round': 33,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 10,
#         'after': {'real': 21, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 187,
#      'data': [{'subiteration': 1,
#        'dices': [4, 6],
#        'round': 33,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 0},
#         'before': 21,
#         'after': {'real': 31, 'updated': 11},
#         'forward': {'real': True, 'updated': False}}}]},
#     {'iteration': 188,
#      'data': [{'subiteration': 1,
#        'dices': [1, 2],
#        'round': 33,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 1},
#         'before': 11,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': None, 'updated': None}}}]},
#     {'iteration': 189,
#      'data': [{'subiteration': 1,
#        'dices': [2, 1],
#        'round': 33,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 2},
#         'before': 11,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': None, 'updated': None}}}]},
#     {'iteration': 190,
#      'data': [{'subiteration': 1,
#        'dices': [1, 5],
#        'round': 33,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 11,
#         'after': {'real': 17, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 191,
#      'data': [{'subiteration': 1,
#        'dices': [5, 5],
#        'round': 33,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 17,
#         'after': {'real': 27, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [4, 6],
#        'round': 34,
#        'move': {'chance_card': 1,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 27,
#         'after': {'real': 37, 'updated': 1},
#         'forward': {'real': True, 'updated': True}}}]},
#     {'iteration': 192,
#      'data': [{'subiteration': 1,
#        'dices': [1, 1],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': 3,
#         'jail': {'status': False, 'number': 0},
#         'before': 1,
#         'after': {'real': 3, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [4, 3],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 3,
#         'after': {'real': 10, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 193,
#      'data': [{'subiteration': 1,
#        'dices': [5, 1],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 10,
#         'after': {'real': 16, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 194,
#      'data': [{'subiteration': 1,
#        'dices': [1, 1],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': 12,
#         'jail': {'status': False, 'number': 0},
#         'before': 16,
#         'after': {'real': 18, 'updated': None},
#         'forward': {'real': True, 'updated': None}}},
#       {'subiteration': 2,
#        'dices': [4, 2],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 18,
#         'after': {'real': 24, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 195,
#      'data': [{'subiteration': 1,
#        'dices': [2, 5],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 0},
#         'before': 24,
#         'after': {'real': 31, 'updated': 11},
#         'forward': {'real': True, 'updated': False}}}]},
#     {'iteration': 196,
#      'data': [{'subiteration': 1,
#        'dices': [6, 3],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 1},
#         'before': 11,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': None, 'updated': None}}}]},
#     {'iteration': 197,
#      'data': [{'subiteration': 1,
#        'dices': [5, 3],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 2},
#         'before': 11,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': None, 'updated': None}}}]},
#     {'iteration': 198,
#      'data': [{'subiteration': 1,
#        'dices': [6, 4],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': False, 'number': 0},
#         'before': 11,
#         'after': {'real': 21, 'updated': None},
#         'forward': {'real': True, 'updated': None}}}]},
#     {'iteration': 199,
#      'data': [{'subiteration': 1,
#        'dices': [5, 5],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 0},
#         'before': 21,
#         'after': {'real': 31, 'updated': 11},
#         'forward': {'real': True, 'updated': False}}},
#       {'subiteration': 2,
#        'dices': [5, 6],
#        'round': 34,
#        'move': {'chance_card': None,
#         'community_card': None,
#         'jail': {'status': True, 'number': 1},
#         'before': 11,
#         'after': {'real': 11, 'updated': None},
#         'forward': {'real': None, 'updated': None}}}]}]}}}

# %% [markdown]
# ### Convert JSON into data frame

# %%
# Flatten the JSON
def flatten_json(
    d: dict
    ):
    # Normalize JSON into data frame
    f = pd.json_normalize(d, sep = '_')
    # Data frame into JSON
    result_json = f.to_dict(orient = 'records')[0]
    
    return result_json

# %%
# Players
players = data_simulation['simulation'].keys()

# Object to store data
obj_simulation = []

# Loop the players
for player in players:
    # Number of iteration
    data_iterations = data_simulation['simulation'][player]['iterations']
    
    # Loop the iteration
    for iter_ in range(len(data_iterations)):
        # Selected iteration
        selected_iteration = data_iterations[iter_]
        # Iteration
        n_iteration = selected_iteration['iteration']
        
        # Loop the subiteration
        for subiter_ in range(len(selected_iteration['data'])):
            # Selected subiteration
            selected_subiteration = selected_iteration['data'][subiter_]
            # Flatten the JSON
            subiteration_reformat = flatten_json(selected_subiteration)
            # Add iteration and player
            new_data = {**{'player': player, 'iteration': n_iteration}, **subiteration_reformat}
            
            # Append into data object
            obj_simulation.append(new_data)

# %%
# Data frame
df = pd.DataFrame(
    data = obj_simulation
)

# %%
# Show the data
df.head(50)
# Out:
#       player  iteration  subiteration   dices  round  move_chance_card  \
# 0   Player 1          0             1  [1, 2]      0               NaN
# 1   Player 1          1             1  [5, 2]      0               NaN
# 2   Player 1          2             1  [1, 2]      0               NaN
# 3   Player 1          3             1  [4, 6]      0               NaN
# 4   Player 1          4             1  [3, 6]      0               NaN
# 5   Player 1          5             1  [2, 3]      0               NaN
# 6   Player 1          6             1  [4, 4]      1               NaN
# 7   Player 1          6             2  [3, 6]      1               NaN
# 8   Player 1          7             1  [3, 4]      1               NaN
# 9   Player 1          8             1  [2, 6]      1               NaN
# 10  Player 1          9             1  [5, 6]      2               NaN
# 11  Player 1         10             1  [6, 1]      2              12.0
# 12  Player 1         11             1  [6, 5]      2               NaN
# 13  Player 1         12             1  [1, 6]      2               NaN
# 14  Player 1         13             1  [2, 2]      2               NaN
# 15  Player 1         13             2  [3, 1]      3               NaN
# 16  Player 1         14             1  [2, 1]      3               NaN
# 17  Player 1         15             1  [5, 1]      3               NaN
# 18  Player 1         16             1  [1, 5]      3               NaN
# 19  Player 1         17             1  [6, 5]      3               NaN
# 20  Player 1         18             1  [4, 1]      3               NaN
# 21  Player 1         19             1  [4, 4]      3               NaN
# 22  Player 1         19             2  [4, 6]      4               NaN
# 23  Player 1         20             1  [1, 4]      4               NaN
# 24  Player 1         21             1  [2, 3]      4               NaN
# 25  Player 1         22             1  [2, 4]      4               NaN
# 26  Player 1         23             1  [3, 1]      4               NaN
# 27  Player 1         24             1  [1, 3]      4               NaN
# 28  Player 1         25             1  [3, 6]      5               NaN
# 29  Player 1         26             1  [6, 4]      5               NaN
# 30  Player 1         27             1  [3, 2]      5               NaN
# 31  Player 1         28             1  [6, 6]      5               NaN
# 32  Player 1         28             2  [1, 3]      6               NaN
# 33  Player 1         29             1  [3, 5]      6               NaN
# 34  Player 1         30             1  [6, 3]      6               NaN
# 35  Player 1         31             1  [4, 3]      6               NaN
# 36  Player 1         32             1  [1, 2]      6               NaN
# 37  Player 1         33             1  [6, 4]      6               3.0
# 38  Player 1         34             1  [2, 4]      7               NaN
# 39  Player 1         35             1  [2, 2]      7               NaN
# 40  Player 1         35             2  [1, 6]      7               NaN
# 41  Player 1         36             1  [5, 5]      7               NaN
# 42  Player 1         36             2  [5, 3]      7               NaN
# 43  Player 1         37             1  [2, 4]      8               NaN
# 44  Player 1         38             1  [3, 6]      8               NaN
# 45  Player 1         39             1  [6, 3]      8               NaN
# 46  Player 1         40             1  [5, 1]      8               NaN
# 47  Player 1         41             1  [5, 5]      8               NaN
# 48  Player 1         41             2  [2, 5]      9               NaN
# 49  Player 1         42             1  [1, 1]      9               NaN
#
#     move_community_card  move_jail_status  move_jail_number  move_before  \
# 0                   NaN             False                 0            1
# 1                   NaN             False                 0            4
# 2                   NaN             False                 0           11
# 3                   NaN             False                 0           14
# 4                   NaN             False                 0           24
# 5                   NaN             False                 0           33
# 6                   NaN             False                 0           38
# 7                   NaN             False                 0            6
# 8                   NaN             False                 0           15
# 9                   NaN             False                 0           22
# 10                  NaN             False                 0           30
# 11                  NaN             False                 0            1
# 12                  NaN             False                 0            8
# 13                  NaN             False                 0           19
# 14                  NaN             False                 0           26
# 15                  1.0             False                 0           30
# 16                  NaN             False                 0            1
# 17                  NaN             False                 0            4
# 18                  NaN             False                 0           10
# 19                  NaN             False                 0           16
# 20                  NaN             False                 0           27
# 21                  NaN             False                 0           32
# 22                  NaN             False                 0           40
# 23                  NaN             False                 0           10
# 24                  NaN             False                 0           15
# 25                  NaN             False                 0           20
# 26                  NaN             False                 0           26
# 27                  7.0             False                 0           30
# 28                  7.0             False                 0           34
# 29                  NaN             False                 0            3
# 30                  9.0             False                 0           13
# 31                  NaN             False                 0           18
# 32                  6.0             False                 0           30
# 33                  NaN             False                 0           11
# 34                  NaN             False                 0           19
# 35                  NaN             False                 0           28
# 36                  NaN             False                 0           35
# 37                  NaN             False                 0           38
# 38                  NaN             False                 0           40
# 39                  NaN             False                 0            6
# 40                  NaN             False                 0           10
# 41                  NaN             False                 0           17
# 42                  NaN             False                 0           27
# 43                  NaN             False                 0           35
# 44                  NaN             False                 0            1
# 45                  NaN             False                 0           10
# 46                  NaN             False                 0           19
# 47                  NaN             False                 0           25
# 48                  NaN             False                 0           35
# 49                  NaN             False                 0            2
#
#     move_after_real  move_after_updated move_forward_real move_forward_updated
# 0                 4                 NaN              True                 None
# 1                11                 NaN              True                 None
# 2                14                 NaN              True                 None
# 3                24                 NaN              True                 None
# 4                33                 NaN              True                 None
# 5                38                 NaN              True                 None
# 6                 6                 NaN              True                 None
# 7                15                 NaN              True                 None
# 8                22                 NaN              True                 None
# 9                30                 NaN              True                 None
# 10                1                 NaN              True                 None
# 11                8                 NaN              True                 None
# 12               19                 NaN              True                 None
# 13               26                 NaN              True                 None
# 14               30                 NaN              True                 None
# 15               34                 1.0              True                 True
# 16                4                 NaN              True                 None
# 17               10                 NaN              True                 None
# 18               16                 NaN              True                 None
# 19               27                 NaN              True                 None
# 20               32                 NaN              True                 None
# 21               40                 NaN              True                 None
# 22               10                 NaN              True                 None
# 23               15                 NaN              True                 None
# 24               20                 NaN              True                 None
# 25               26                 NaN              True                 None
# 26               30                 NaN              True                 None
# 27               34                 NaN              True                 None
# 28                3                 NaN              True                 None
# 29               13                 NaN              True                 None
# 30               18                 NaN              True                 None
# 31               30                 NaN              True                 None
# 32               34                11.0              True                 True
# 33               19                 NaN              True                 None
# 34               28                 NaN              True                 None
# 35               35                 NaN              True                 None
# 36               38                 NaN              True                 None
# 37                8                40.0              True                 True
# 38                6                 NaN              True                 None
# 39               10                 NaN              True                 None
# 40               17                 NaN              True                 None
# 41               27                 NaN              True                 None
# 42               35                 NaN              True                 None
# 43                1                 NaN              True                 None
# 44               10                 NaN              True                 None
# 45               19                 NaN              True                 None
# 46               25                 NaN              True                 None
# 47               35                 NaN              True                 None
# 48                2                 NaN              True                 None
# 49                4                 NaN              True                 None

# %%
dict(df['move_after_real'].value_counts())
# Out:
# {11: 8439,
#  19: 3391,
#  21: 3365,
#  17: 3252,
#  23: 3215,
#  20: 3214,
#  18: 3185,
#  22: 3178,
#  26: 3100,
#  24: 3070,
#  31: 3050,
#  27: 3015,
#  32: 3006,
#  29: 2999,
#  33: 2977,
#  25: 2969,
#  28: 2953,
#  16: 2950,
#  30: 2932,
#  13: 2893,
#  35: 2876,
#  15: 2855,
#  34: 2847,
#  36: 2756,
#  10: 2692,
#  9: 2691,
#  14: 2646,
#  8: 2623,
#  37: 2616,
#  6: 2570,
#  12: 2547,
#  4: 2537,
#  5: 2534,
#  7: 2528,
#  40: 2525,
#  3: 2524,
#  39: 2515,
#  2: 2474,
#  38: 2445,
#  1: 2418}
